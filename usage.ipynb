# %%
from PIL import Image
from pprint import pprint
import os
import pandas as pd

from model.cnn import SSD
from utils.dataloader import gen_bccd_dataloader
from utils.manager import Manager

# %%
model = SSD()
object_detector = Manager(model=model)
dataloader = gen_bccd_dataloader()

# %%
train_log = object_detector.train(
    num_epochs=30, 
    dataloader=dataloader,
    print_iter=True)
# Out:
# Epoch 1/30 ----------------
#     iteration 10 | Loss_c: 47.8422 | Loss_l: 8.0089
#     iteration 20 | Loss_c: 7.7159 | Loss_l: 3.2389
#     iteration 30 | Loss_c: 4.2226 | Loss_l: 3.4229
#     iteration 40 | Loss_c: 5.9585 | Loss_l: 2.5210
#     iteration 50 | Loss_c: 4.3915 | Loss_l: 2.3522
#     iteration 60 | Loss_c: 3.3257 | Loss_l: 2.1067
#     iteration 70 | Loss_c: 2.7068 | Loss_l: 1.7389
#     TRAIN | epoch_loss_l: 477.0766, epoch_loss_c: 1787.2908
#     batch elasped time:  89.8431 sec.
# Epoch 2/30 ----------------
#     iteration 80 | Loss_c: 2.8288 | Loss_l: 2.0524
#     iteration 90 | Loss_c: 4.2548 | Loss_l: 1.3734
#     iteration 100 | Loss_c: 3.8599 | Loss_l: 1.7847
#     iteration 110 | Loss_c: 2.9443 | Loss_l: 2.0830
#     iteration 120 | Loss_c: 3.3963 | Loss_l: 1.7209
#     iteration 130 | Loss_c: 2.4284 | Loss_l: 1.4271
#     iteration 140 | Loss_c: 3.4101 | Loss_l: 2.0877
#     TRAIN | epoch_loss_l: 127.6266, epoch_loss_c: 205.9933
#     batch elasped time:  90.9368 sec.
# Epoch 3/30 ----------------
#     iteration 150 | Loss_c: 2.4004 | Loss_l: 1.6155
#     iteration 160 | Loss_c: 2.7778 | Loss_l: 2.1195
#     iteration 170 | Loss_c: 2.3309 | Loss_l: 1.4754
#     iteration 180 | Loss_c: 2.0771 | Loss_l: 1.7902
#     iteration 190 | Loss_c: 1.9767 | Loss_l: 1.4670
#     iteration 200 | Loss_c: 2.0352 | Loss_l: 1.2962
#     iteration 210 | Loss_c: 2.0044 | Loss_l: 1.4969
#     TRAIN | epoch_loss_l: 109.3906, epoch_loss_c: 172.1739
#     batch elasped time:  94.3857 sec.
# Epoch 4/30 ----------------
#     iteration 220 | Loss_c: 1.7742 | Loss_l: 1.6299
#     iteration 230 | Loss_c: 1.9150 | Loss_l: 0.8770
#     iteration 240 | Loss_c: 1.6168 | Loss_l: 1.0820
#     iteration 250 | Loss_c: 1.8871 | Loss_l: 0.8481
#     iteration 260 | Loss_c: 1.5545 | Loss_l: 0.9131
#     iteration 270 | Loss_c: 2.1449 | Loss_l: 1.3443
#     iteration 280 | Loss_c: 1.6892 | Loss_l: 1.2611
#     TRAIN | epoch_loss_l: 88.5851, epoch_loss_c: 141.3943
#     batch elasped time:  93.1421 sec.
# Epoch 5/30 ----------------
#     iteration 290 | Loss_c: 1.8198 | Loss_l: 0.8448
#     iteration 300 | Loss_c: 1.8215 | Loss_l: 1.2230
#     iteration 310 | Loss_c: 1.7865 | Loss_l: 0.5650
#     iteration 320 | Loss_c: 1.5802 | Loss_l: 1.1968
#     iteration 330 | Loss_c: 1.5167 | Loss_l: 0.8248
#     iteration 340 | Loss_c: 1.2690 | Loss_l: 0.5824
#     iteration 350 | Loss_c: 1.6525 | Loss_l: 1.0487
#     iteration 360 | Loss_c: 1.6654 | Loss_l: 0.7360
#     TRAIN | epoch_loss_l: 74.1699, epoch_loss_c: 122.9142
#     batch elasped time:  91.6297 sec.
# Epoch 6/30 ----------------
#     iteration 370 | Loss_c: 1.3936 | Loss_l: 0.9406
#     iteration 380 | Loss_c: 1.2257 | Loss_l: 0.6243
#     iteration 390 | Loss_c: 2.5686 | Loss_l: 1.3735
#     iteration 400 | Loss_c: 2.0756 | Loss_l: 0.8212
#     iteration 410 | Loss_c: 1.3974 | Loss_l: 1.0893
#     iteration 420 | Loss_c: 1.8248 | Loss_l: 0.9590
#     iteration 430 | Loss_c: 1.8451 | Loss_l: 1.4771
#     TRAIN | epoch_loss_l: 71.3721, epoch_loss_c: 119.7810
#     batch elasped time:  92.1234 sec.
# Epoch 7/30 ----------------
#     iteration 440 | Loss_c: 1.4895 | Loss_l: 0.9817
#     iteration 450 | Loss_c: 1.4570 | Loss_l: 1.0048
#     iteration 460 | Loss_c: 1.7630 | Loss_l: 0.9241
#     iteration 470 | Loss_c: 1.3488 | Loss_l: 0.4907
#     iteration 480 | Loss_c: 1.1036 | Loss_l: 0.6783
#     iteration 490 | Loss_c: 1.4437 | Loss_l: 0.9168
#     iteration 500 | Loss_c: 1.3493 | Loss_l: 1.0599
#     TRAIN | epoch_loss_l: 63.1567, epoch_loss_c: 104.2251
#     batch elasped time:  92.0721 sec.
# Epoch 8/30 ----------------
#     iteration 510 | Loss_c: 1.2507 | Loss_l: 0.5962
#     iteration 520 | Loss_c: 1.1741 | Loss_l: 0.6593
#     iteration 530 | Loss_c: 1.3094 | Loss_l: 0.9020
#     iteration 540 | Loss_c: 1.8009 | Loss_l: 0.6800
#     iteration 550 | Loss_c: 1.3376 | Loss_l: 0.9923
#     iteration 560 | Loss_c: 1.1360 | Loss_l: 0.9945
#     iteration 570 | Loss_c: 1.4482 | Loss_l: 0.8249
#     TRAIN | epoch_loss_l: 61.2876, epoch_loss_c: 105.1909
#     batch elasped time:  91.5321 sec.
# Epoch 9/30 ----------------
#     iteration 580 | Loss_c: 1.2221 | Loss_l: 0.7765
#     iteration 590 | Loss_c: 1.2212 | Loss_l: 0.6005
#     iteration 600 | Loss_c: 1.3003 | Loss_l: 1.0490
#     iteration 610 | Loss_c: 1.8490 | Loss_l: 0.6345
#     iteration 620 | Loss_c: 1.3062 | Loss_l: 0.7246
#     iteration 630 | Loss_c: 1.1160 | Loss_l: 0.5187
#     iteration 640 | Loss_c: 1.1674 | Loss_l: 0.8986
#     TRAIN | epoch_loss_l: 54.9109, epoch_loss_c: 102.9780
#     batch elasped time:  91.3410 sec.
# Epoch 10/30 ----------------
#     iteration 650 | Loss_c: 1.2726 | Loss_l: 0.3394
#     iteration 660 | Loss_c: 1.3290 | Loss_l: 0.5616
#     iteration 670 | Loss_c: 1.0490 | Loss_l: 0.3635
#     iteration 680 | Loss_c: 1.3468 | Loss_l: 0.9362
#     iteration 690 | Loss_c: 2.0457 | Loss_l: 0.8356
#     iteration 700 | Loss_c: 1.2822 | Loss_l: 0.7578
#     iteration 710 | Loss_c: 1.7265 | Loss_l: 0.7988
#     iteration 720 | Loss_c: 0.9321 | Loss_l: 0.4170
#     TRAIN | epoch_loss_l: 52.9051, epoch_loss_c: 99.0711
#     VAL | epoch_loss_l: 16.0984, epoch_loss_c: 26.2343
#     batch elasped time:  100.6018 sec.
# Epoch 11/30 ----------------
#     iteration 730 | Loss_c: 0.7459 | Loss_l: 0.6594
#     iteration 740 | Loss_c: 2.5927 | Loss_l: 1.4457
#     iteration 750 | Loss_c: 1.2363 | Loss_l: 0.8839
#     iteration 760 | Loss_c: 1.3460 | Loss_l: 0.6838
#     iteration 770 | Loss_c: 0.9329 | Loss_l: 0.8055
#     iteration 780 | Loss_c: 1.3170 | Loss_l: 0.5309
#     iteration 790 | Loss_c: 1.3130 | Loss_l: 0.5749
#     TRAIN | epoch_loss_l: 51.5609, epoch_loss_c: 94.7923
#     batch elasped time:  91.3917 sec.
# Epoch 12/30 ----------------
#     iteration 800 | Loss_c: 1.0076 | Loss_l: 0.5005
#     iteration 810 | Loss_c: 1.2302 | Loss_l: 0.4755
#     iteration 820 | Loss_c: 1.3968 | Loss_l: 0.7636
#     iteration 830 | Loss_c: 1.0624 | Loss_l: 0.4381
#     iteration 840 | Loss_c: 1.4734 | Loss_l: 1.0678
#     iteration 850 | Loss_c: 1.1516 | Loss_l: 0.6439
#     iteration 860 | Loss_c: 1.5661 | Loss_l: 0.5867
#     TRAIN | epoch_loss_l: 47.2661, epoch_loss_c: 93.4861
#     batch elasped time:  96.8089 sec.
# Epoch 13/30 ----------------
#     iteration 870 | Loss_c: 1.0977 | Loss_l: 0.5969
#     iteration 880 | Loss_c: 0.8692 | Loss_l: 0.5258
#     iteration 890 | Loss_c: 1.0971 | Loss_l: 0.6868
#     iteration 900 | Loss_c: 1.2127 | Loss_l: 0.7975
#     iteration 910 | Loss_c: 0.9039 | Loss_l: 0.7313
#     iteration 920 | Loss_c: 1.1914 | Loss_l: 0.9939
#     iteration 930 | Loss_c: 0.9959 | Loss_l: 0.6286
#     TRAIN | epoch_loss_l: 46.5563, epoch_loss_c: 85.7249
#     batch elasped time:  92.5876 sec.
# Epoch 14/30 ----------------
#     iteration 940 | Loss_c: 1.1098 | Loss_l: 0.4694
#     iteration 950 | Loss_c: 1.3763 | Loss_l: 0.5957
#     iteration 960 | Loss_c: 1.0374 | Loss_l: 0.7507
#     iteration 970 | Loss_c: 1.1619 | Loss_l: 0.7163
#     iteration 980 | Loss_c: 1.8140 | Loss_l: 0.9295
#     iteration 990 | Loss_c: 1.3191 | Loss_l: 0.8547
#     iteration 1000 | Loss_c: 1.9559 | Loss_l: 0.8545
#     TRAIN | epoch_loss_l: 51.1251, epoch_loss_c: 93.1171
#     batch elasped time:  92.0824 sec.
# Epoch 15/30 ----------------
#     iteration 1010 | Loss_c: 1.2312 | Loss_l: 0.6014
#     iteration 1020 | Loss_c: 1.9938 | Loss_l: 0.7866
#     iteration 1030 | Loss_c: 1.4725 | Loss_l: 0.7647
#     iteration 1040 | Loss_c: 0.8771 | Loss_l: 0.4628
#     iteration 1050 | Loss_c: 1.2143 | Loss_l: 0.2405
#     iteration 1060 | Loss_c: 1.1187 | Loss_l: 0.5519
#     iteration 1070 | Loss_c: 0.8393 | Loss_l: 0.4954
#     iteration 1080 | Loss_c: 1.7545 | Loss_l: 0.5955
#     TRAIN | epoch_loss_l: 45.7323, epoch_loss_c: 88.0873
#     batch elasped time:  92.5884 sec.
# Epoch 16/30 ----------------
#     iteration 1090 | Loss_c: 1.1297 | Loss_l: 0.9806
#     iteration 1100 | Loss_c: 1.1437 | Loss_l: 0.2666
#     iteration 1110 | Loss_c: 0.7474 | Loss_l: 0.6798
#     iteration 1120 | Loss_c: 1.0224 | Loss_l: 0.5925
#     iteration 1130 | Loss_c: 3.1077 | Loss_l: 0.7231
#     iteration 1140 | Loss_c: 0.9747 | Loss_l: 0.4510
#     iteration 1150 | Loss_c: 1.1962 | Loss_l: 0.5327
#     TRAIN | epoch_loss_l: 40.9942, epoch_loss_c: 85.1850
#     batch elasped time:  91.9049 sec.
# Epoch 17/30 ----------------
#     iteration 1160 | Loss_c: 1.2286 | Loss_l: 0.7298
#     iteration 1170 | Loss_c: 1.3579 | Loss_l: 0.6441
#     iteration 1180 | Loss_c: 0.8462 | Loss_l: 0.4674
#     iteration 1190 | Loss_c: 1.0040 | Loss_l: 0.5041
#     iteration 1200 | Loss_c: 1.5153 | Loss_l: 0.5898
#     iteration 1210 | Loss_c: 0.8896 | Loss_l: 0.3572
#     iteration 1220 | Loss_c: 0.9265 | Loss_l: 0.5535
#     TRAIN | epoch_loss_l: 44.0099, epoch_loss_c: 84.4099
#     batch elasped time:  91.8808 sec.
# Epoch 18/30 ----------------
#     iteration 1230 | Loss_c: 0.8975 | Loss_l: 0.4019
#     iteration 1240 | Loss_c: 1.2021 | Loss_l: 0.7779
#     iteration 1250 | Loss_c: 0.9917 | Loss_l: 0.7101
#     iteration 1260 | Loss_c: 0.9580 | Loss_l: 0.5367
#     iteration 1270 | Loss_c: 1.2582 | Loss_l: 0.6688
#     iteration 1280 | Loss_c: 1.7512 | Loss_l: 1.3067
#     iteration 1290 | Loss_c: 1.2924 | Loss_l: 0.6272
#     TRAIN | epoch_loss_l: 40.0684, epoch_loss_c: 82.2434
#     batch elasped time:  92.1931 sec.
# Epoch 19/30 ----------------
#     iteration 1300 | Loss_c: 1.0037 | Loss_l: 0.6433
#     iteration 1310 | Loss_c: 1.6457 | Loss_l: 0.5043
#     iteration 1320 | Loss_c: 1.1473 | Loss_l: 0.7624
#     iteration 1330 | Loss_c: 0.7919 | Loss_l: 0.6159
#     iteration 1340 | Loss_c: 1.3394 | Loss_l: 0.2771
#     iteration 1350 | Loss_c: 1.1394 | Loss_l: 1.0136
#     iteration 1360 | Loss_c: 0.8502 | Loss_l: 0.4847
#     TRAIN | epoch_loss_l: 41.7732, epoch_loss_c: 80.6444
#     batch elasped time:  91.3673 sec.
# Epoch 20/30 ----------------
#     iteration 1370 | Loss_c: 1.0970 | Loss_l: 0.6267
#     iteration 1380 | Loss_c: 0.6394 | Loss_l: 0.3719
#     iteration 1390 | Loss_c: 0.9041 | Loss_l: 0.4729
#     iteration 1400 | Loss_c: 0.6672 | Loss_l: 0.4121
#     iteration 1410 | Loss_c: 1.0141 | Loss_l: 0.4948
#     iteration 1420 | Loss_c: 1.0422 | Loss_l: 0.4995
#     iteration 1430 | Loss_c: 1.1953 | Loss_l: 0.4773
#     iteration 1440 | Loss_c: 2.4658 | Loss_l: 0.3784
#     TRAIN | epoch_loss_l: 38.6276, epoch_loss_c: 78.5614
#     VAL | epoch_loss_l: 15.5728, epoch_loss_c: 25.6743
#     batch elasped time:  100.8706 sec.
# Epoch 21/30 ----------------
#     iteration 1450 | Loss_c: 1.1886 | Loss_l: 0.5554
#     iteration 1460 | Loss_c: 0.8918 | Loss_l: 0.5233
#     iteration 1470 | Loss_c: 1.3486 | Loss_l: 0.4243
#     iteration 1480 | Loss_c: 0.7256 | Loss_l: 0.2819
#     iteration 1490 | Loss_c: 1.7090 | Loss_l: 1.0665
#     iteration 1500 | Loss_c: 0.8867 | Loss_l: 0.4884
#     iteration 1510 | Loss_c: 0.6532 | Loss_l: 0.4150
#     TRAIN | epoch_loss_l: 37.4338, epoch_loss_c: 82.3777
#     batch elasped time:  91.8177 sec.
# Epoch 22/30 ----------------
#     iteration 1520 | Loss_c: 0.7236 | Loss_l: 0.3254
#     iteration 1530 | Loss_c: 0.7931 | Loss_l: 0.6029
#     iteration 1540 | Loss_c: 1.0115 | Loss_l: 0.6241
#     iteration 1550 | Loss_c: 1.1199 | Loss_l: 0.3613
#     iteration 1560 | Loss_c: 0.8052 | Loss_l: 0.5328
#     iteration 1570 | Loss_c: 1.2218 | Loss_l: 0.5060
#     iteration 1580 | Loss_c: 1.1942 | Loss_l: 0.5078
#     TRAIN | epoch_loss_l: 41.1750, epoch_loss_c: 86.6124
#     batch elasped time:  92.2160 sec.
# Epoch 23/30 ----------------
#     iteration 1590 | Loss_c: 0.8647 | Loss_l: 0.7346
#     iteration 1600 | Loss_c: 0.5780 | Loss_l: 0.2785
#     iteration 1610 | Loss_c: 1.4063 | Loss_l: 0.8289
#     iteration 1620 | Loss_c: 1.5297 | Loss_l: 0.9190
#     iteration 1630 | Loss_c: 0.8700 | Loss_l: 0.5209
#     iteration 1640 | Loss_c: 0.8628 | Loss_l: 0.3880
#     iteration 1650 | Loss_c: 1.2522 | Loss_l: 0.3653
#     TRAIN | epoch_loss_l: 36.9542, epoch_loss_c: 72.1611
#     batch elasped time:  92.0825 sec.
# Epoch 24/30 ----------------
#     iteration 1660 | Loss_c: 0.8688 | Loss_l: 0.4705
#     iteration 1670 | Loss_c: 1.6218 | Loss_l: 0.4500
#     iteration 1680 | Loss_c: 1.3052 | Loss_l: 0.6523
#     iteration 1690 | Loss_c: 1.1398 | Loss_l: 0.5353
#     iteration 1700 | Loss_c: 0.6484 | Loss_l: 0.3211
#     iteration 1710 | Loss_c: 1.0767 | Loss_l: 0.3686
#     iteration 1720 | Loss_c: 0.9780 | Loss_l: 0.4130
#     TRAIN | epoch_loss_l: 34.7128, epoch_loss_c: 66.9655
#     batch elasped time:  92.0020 sec.
# Epoch 25/30 ----------------
#     iteration 1730 | Loss_c: 0.9022 | Loss_l: 0.7276
#     iteration 1740 | Loss_c: 0.4914 | Loss_l: 0.2330
#     iteration 1750 | Loss_c: 0.9006 | Loss_l: 0.6542
#     iteration 1760 | Loss_c: 0.8425 | Loss_l: 0.4163
#     iteration 1770 | Loss_c: 0.7462 | Loss_l: 0.4320
#     iteration 1780 | Loss_c: 1.5952 | Loss_l: 0.6038
#     iteration 1790 | Loss_c: 1.1395 | Loss_l: 0.9123
#     iteration 1800 | Loss_c: 0.6664 | Loss_l: 0.4932
#     TRAIN | epoch_loss_l: 33.1870, epoch_loss_c: 66.9488
#     batch elasped time:  91.7146 sec.
# Epoch 26/30 ----------------
#     iteration 1810 | Loss_c: 0.6565 | Loss_l: 0.3438
#     iteration 1820 | Loss_c: 0.9378 | Loss_l: 0.3546
#     iteration 1830 | Loss_c: 1.1586 | Loss_l: 0.6674
#     iteration 1840 | Loss_c: 1.1148 | Loss_l: 0.5462
#     iteration 1850 | Loss_c: 1.2242 | Loss_l: 0.5513
#     iteration 1860 | Loss_c: 0.7753 | Loss_l: 0.5200
#     iteration 1870 | Loss_c: 0.6473 | Loss_l: 0.2451
#     TRAIN | epoch_loss_l: 33.8599, epoch_loss_c: 63.2368
#     batch elasped time:  91.8449 sec.
# Epoch 27/30 ----------------
#     iteration 1880 | Loss_c: 0.8658 | Loss_l: 0.3855
#     iteration 1890 | Loss_c: 0.9856 | Loss_l: 0.5733
#     iteration 1900 | Loss_c: 2.4192 | Loss_l: 0.6758
#     iteration 1910 | Loss_c: 0.9533 | Loss_l: 0.4810
#     iteration 1920 | Loss_c: 0.9290 | Loss_l: 0.4706
#     iteration 1930 | Loss_c: 0.9257 | Loss_l: 0.3911
#     iteration 1940 | Loss_c: 0.9405 | Loss_l: 0.5092
#     TRAIN | epoch_loss_l: 34.2160, epoch_loss_c: 73.6092
#     batch elasped time:  92.0528 sec.
# Epoch 28/30 ----------------
#     iteration 1950 | Loss_c: 0.7532 | Loss_l: 0.4043
#     iteration 1960 | Loss_c: 1.0186 | Loss_l: 0.4999
#     iteration 1970 | Loss_c: 0.8359 | Loss_l: 0.4949
#     iteration 1980 | Loss_c: 1.0891 | Loss_l: 0.6069
#     iteration 1990 | Loss_c: 0.8408 | Loss_l: 0.4288
#     iteration 2000 | Loss_c: 0.8815 | Loss_l: 0.4513
#     iteration 2010 | Loss_c: 1.6379 | Loss_l: 0.3169
#     TRAIN | epoch_loss_l: 35.8752, epoch_loss_c: 75.6706
#     batch elasped time:  92.0018 sec.
# Epoch 29/30 ----------------
#     iteration 2020 | Loss_c: 0.6460 | Loss_l: 0.3451
#     iteration 2030 | Loss_c: 1.3142 | Loss_l: 0.2963
#     iteration 2040 | Loss_c: 1.1769 | Loss_l: 0.4516
#     iteration 2050 | Loss_c: 1.0286 | Loss_l: 0.3285
#     iteration 2060 | Loss_c: 1.0222 | Loss_l: 0.7907
#     iteration 2070 | Loss_c: 0.6090 | Loss_l: 0.4347
#     iteration 2080 | Loss_c: 1.2484 | Loss_l: 0.5090
#     TRAIN | epoch_loss_l: 31.7336, epoch_loss_c: 65.4794
#     batch elasped time:  93.2493 sec.
# Epoch 30/30 ----------------
#     iteration 2090 | Loss_c: 0.9746 | Loss_l: 0.2632
#     iteration 2100 | Loss_c: 0.6102 | Loss_l: 0.4093
#     iteration 2110 | Loss_c: 1.2681 | Loss_l: 0.3870
#     iteration 2120 | Loss_c: 0.6691 | Loss_l: 0.2943
#     iteration 2130 | Loss_c: 0.9658 | Loss_l: 0.3973
#     iteration 2140 | Loss_c: 1.2183 | Loss_l: 0.5794
#     iteration 2150 | Loss_c: 0.6595 | Loss_l: 0.3370
#     iteration 2160 | Loss_c: 0.6304 | Loss_l: 0.3660
#     TRAIN | epoch_loss_l: 29.3963, epoch_loss_c: 59.8218
#     VAL | epoch_loss_l: 13.9242, epoch_loss_c: 25.2456
#     batch elasped time:  101.3860 sec.

# %%
df_log = pd.DataFrame(train_log)
df_log
# Out:
#     epoch  train_loss_c  train_loss_l  val_loss_c  val_loss_l
# 0       1   1787.290831    477.076561         NaN         NaN
# 1       2    205.993291    127.626649         NaN         NaN
# 2       3    172.173890    109.390617         NaN         NaN
# 3       4    141.394314     88.585113         NaN         NaN
# 4       5    122.914198     74.169889         NaN         NaN
# 5       6    119.781027     71.372050         NaN         NaN
# 6       7    104.225117     63.156745         NaN         NaN
# 7       8    105.190948     61.287553         NaN         NaN
# 8       9    102.977958     54.910949         NaN         NaN
# 9      10     99.071089     52.905067   16.098387   16.098387
# 10     11     94.792298     51.560930         NaN         NaN
# 11     12     93.486079     47.266112         NaN         NaN
# 12     13     85.724864     46.556328         NaN         NaN
# 13     14     93.117098     51.125086         NaN         NaN
# 14     15     88.087334     45.732311         NaN         NaN
# 15     16     85.184965     40.994241         NaN         NaN
# 16     17     84.409895     44.009860         NaN         NaN
# 17     18     82.243441     40.068367         NaN         NaN
# 18     19     80.644396     41.773170         NaN         NaN
# 19     20     78.561440     38.627589   15.572846   15.572846
# 20     21     82.377706     37.433776         NaN         NaN
# 21     22     86.612363     41.175015         NaN         NaN
# 22     23     72.161074     36.954197         NaN         NaN
# 23     24     66.965545     34.712840         NaN         NaN
# 24     25     66.948849     33.186989         NaN         NaN
# 25     26     63.236776     33.859945         NaN         NaN
# 26     27     73.609167     34.215950         NaN         NaN
# 27     28     75.670561     35.875166         NaN         NaN
# 28     29     65.479397     31.733609         NaN         NaN
# 29     30     59.821759     29.396274   13.924181   13.924181

# %%
model.save_weight(fname="pytorch_ssd.pth")

# %%
another_model = SSD()
another_model.load_weight(fname="pytorch_ssd.pth")

# %%
validation_data_index = 10

dataloader.dataset.set_mode(mode="val")
fpath = dataloader.dataset.img_file_name(index=validation_data_index)
print(fpath)

img_pil = Image.open(fpath)
another_object_detector = Manager(model=another_model)
list_box, list_label, list_conf = another_object_detector.predict(img_pil=img_pil)

df_bbox = pd.DataFrame(
    list(zip(list_label, list_conf, list_box)), 
    columns=['label', 'confidence', 'box_cordinate'])
df_bbox
# Out:
# BCCD_Dataset\BCCD\JPEGImages\BloodImage_00341.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
#   label  confidence        box_cordinate
# 0   WBC    0.994613  [354, 66, 566, 300]

# %%
annotated_img = another_object_detector.annotated_img(
    img_pil=img_pil, 
    list_box=list_box, 
    list_label=list_label, 
    list_conf=list_conf)

annotated_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x20B856B5C18>
